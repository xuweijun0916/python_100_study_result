# %% [markdown]
# ### Python内置的@property装饰器就是负责把一个方法变成属性调用的

# %%
class Person(object):
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    # 访问器 - getter方法
    @property
    def name(self):
        return self._name
    
    # 访问器 - getter方法
    @property
    def age(self):
        return self._age
    
    # 修改器 - setter方法
    @age.setter
    def age(self,age):
        self._age = age
        
    def play(self):
        if self._age <= 16:
            print(f'{self._name}在玩飞行棋')
        else:
            print(f'{self._name}在玩斗地主')
            
def main():
    person = Person('大吃',12)
    person.play()
    person.age = 23
    person.play()
    
if __name__ == '__main__':
    main()
# Out:
# 大吃在玩飞行棋
# 大吃在玩斗地主

# %% [markdown]
# ### Python允许在定义class的时候，定义一个特殊的__slots__变量，来限制该class能添加的属性

# %%
class Person(object):
    
    # 限定Person对象只能绑定_name, _age, _gender属性
    __slots__ = ('_name','_age','_gender')
    
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    # 访问器 - getter方法
    @property
    def name(self):
        return self._name
    
    # 访问器 - getter方法
    @property
    def age(self):
        return self._age
    
    # 修改器 - setter方法
    @age.setter
    def age(self,age):
        self._age = age
        
    def play(self):
        if self._age <= 16:
            print(f'{self._name}在玩飞行棋')
        else:
            print(f'{self._name}在玩斗地主')
            
def main():
    person = Person('大吃',12)
    person.play()
    person.gender = '男'
    
if __name__ == '__main__':
    main()
# Out:
# 大吃在玩飞行棋
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-594e231a99c4> in <module>()
#      35
#      36 if __name__ == '__main__':
# ---> 37     main()
#      38
#
# <ipython-input-6-594e231a99c4> in main()
#      32     person = Person('大吃',12)
#      33     person.play()
# ---> 34     person.gender = '男'
#      35
#      36 if __name__ == '__main__':
#
# AttributeError: 'Person' object has no attribute 'gender'

# %%
# 静态方法
"""
我们写在类中的方法并不需要都是对象方法，
例如我们定义一个“三角形”类，通过传入三条边长来构造三角形，
并提供计算周长和面积的方法，但是传入的三条边长未必能构造出三角形对象，
因此我们可以先写一个方法来验证三条边长是否可以构成三角形，
这个方法很显然就不是对象方法，因为在调用这个方法时三角形对象尚未创建出来（因为都不知道三条边能不能构成三角形），
所以这个方法是属于三角形类而并不属于三角形对象的。
我们可以使用静态方法来解决这类问题，代码如下所示。
"""
from math import sqrt

class Triangle(object):
    def __init__(self, a, b, c):
        self._a = a
        self._b = b
        self._c = c
    
    @staticmethod
    def is_valid(a, b, c):
        return a+b > c and a+c > b and b+c >a
    
    def perimeter(self):
        return self._a + self._b + self._c
    
    def area(self):
        half = self.perimeter() / 2
        return sqrt(half*(half-self._a)*(half-self._b)*(half-self._c))

def main():
    a,b,c = 3,4,5
    if Triangle.is_valid(a,b,c):
        t = Triangle(a,b,c)
        print(t.perimeter())
        print(t.area())
    else:
        print('无法构成三角形')
        
if __name__ == '__main__':
    main()
# Out:
# 12
# 6.0

# %%
# 类方法
from time import time,localtime,sleep

class Clock(object):
    """数字时钟"""

    def __init__(self, hour=0, minute=0, second=0):
        self._hour = hour
        self._minute = minute
        self._second = second
        
    @classmethod
    def now(cls):
        ctime = locatime(time())
        return cls(ctime.tm_hour, ctime.tm_min, ctime.tm_sec)
    
    def run(self):
        """走字"""
        self._second += 1
        if self._second == 60:
            self._second = 0
            self._minute += 1
            if self._minute == 60:
                self._minute = 0
                self._hour += 1
                if self._hour == 24:
                    self._hour = 0

    def show(self):
        """显示时间"""
        return '%02d:%02d:%02d' % \
               (self._hour, self._minute, self._second)


def main():
    # 通过类方法创建对象并获取系统时间
    clock = Clock.now()
    while True:
        print(clock.show())
        sleep(1)
        clock.run()


if __name__ == '__main__':
    main()

# %%
# 继承
class Person(object):
    """人"""
    
    def __init__(self,name,age):
        self._name = name
        self._age = age
        
    @property
    def name(self):
        return self._name
    
    @property
    def age(self):
        return self._age
    
    @age.setter
    def age(self):
        self._age = age
        
    def play(self):
        print(f'{self._name}在玩耍')
        
    def watch_tv(self):
        if self.age < 18:
            print(f'{self._name}快去写作业')
        else:
            print(f'{self._name}在看av')
            
class Student(Person):
    def __init__(self,name,age,grade):
        super().__init__(name,age)
        self._grade = grade
        
    @property
    def grade(self):
        return self._grade
    
    @grade.setter
    def grade(self):
        self._grade = grade
        
    def study(self, course):
        print(f'{self._name}在学习{course}')
        
class Teacher(Person):
    def __init__(self,name,age,title):
        super().__init__(name,age)
        self._title = title
        
    @property
    def title(self):
        return self._title
    
    @title.setter
    def title(self):
        self._title = title
        
    def teach(self, course):
        print(f'{self._name}在教{course}')
        
def main():
    stu = Student('张一',18,'高一')
    stu.study('哲学')
    stu.watch_tv()
    t = Teacher('刘莉',27,'地理老师')
    t.teach('地理')
    t.watch_tv()

if __name__ == '__main__':
    main()
# Out:
# 张一在学习哲学
# 张一在看av
# 刘莉在教地理
# 刘莉在看av

# %%
# 重写：子类在继承了父类的方法后，可以对父类已有的方法给出新的实现版本，这个动作称之为方法重写（override）
# 多态：通过方法重写我们可以让父类的同一个行为在子类中拥有不同的实现版本，当我们调用这个经过子类重写的方法时，不同的子类对象会表现出不同的行为，这个就是多态（poly-morphism）。

#抽象方法表示基类的一个方法，没有实现，所以基类不能实例化，子类实现了该抽象方法才能被实例化。
#Python的abc提供了@abstractmethod装饰器实现抽象方法

from abc import ABCMeta, abstractmethod

class Pet(object, metaclass=ABCMeta):
    """宠物"""
    def __init__(self, nickname):
        self._nickname = nickname
        
    @abstractmethod
    def make_voice(self):
        """发出声音"""
        pass
    
class Dog(Pet):
    """狗"""
    def make_voice(self):
        print(f'{self._nickname}:汪汪汪...')
        
class Cat(Pet):
    """猫"""
    def make_voice(self):
        print(f'{self._nickname}:喵喵喵...')
        
def main():
    pets = [Dog('旺财'),Cat('开踢'),Dog('妙妙')]
    for pet in pets:
        pet.make_voice()
        
if __name__ == '__main__':
    main()
# Out:
# 旺财:汪汪汪...
# 开踢:喵喵喵...
# 妙妙:汪汪汪...

# %%
from abc import ABCMeta, abstractmethod
from random import randint, randrange


class Fighter(object, metaclass=ABCMeta):
    """战斗者"""

    # 通过__slots__魔法限定对象可以绑定的成员变量
    __slots__ = ('_name', '_hp')

    def __init__(self, name, hp):
        """初始化方法

        :param name: 名字
        :param hp: 生命值
        """
        self._name = name
        self._hp = hp

    @property
    def name(self):
        return self._name

    @property
    def hp(self):
        return self._hp

    @hp.setter
    def hp(self, hp):
        self._hp = hp if hp >= 0 else 0

    @property
    def alive(self):
        return self._hp > 0

    @abstractmethod
    def attack(self, other):
        """攻击

        :param other: 被攻击的对象
        """
        pass


class Ultraman(Fighter):
    """奥特曼"""

    __slots__ = ('_name', '_hp', '_mp')

    def __init__(self, name, hp, mp):
        """初始化方法

        :param name: 名字
        :param hp: 生命值
        :param mp: 魔法值
        """
        super().__init__(name, hp)
        self._mp = mp

    def attack(self, other):
        other.hp -= randint(15, 25)

    def huge_attack(self, other):
        """究极必杀技(打掉对方至少50点或四分之三的血)

        :param other: 被攻击的对象

        :return: 使用成功返回True否则返回False
        """
        if self._mp >= 50:
            self._mp -= 50
            injury = other.hp * 3 // 4
            injury = injury if injury >= 50 else 50
            other.hp -= injury
            return True
        else:
            self.attack(other)
            return False

    def magic_attack(self, others):
        """魔法攻击

        :param others: 被攻击的群体

        :return: 使用魔法成功返回True否则返回False
        """
        if self._mp >= 20:
            self._mp -= 20
            for temp in others:
                if temp.alive:
                    temp.hp -= randint(10, 15)
            return True
        else:
            return False

    def resume(self):
        """恢复魔法值"""
        incr_point = randint(1, 10)
        self._mp += incr_point
        return incr_point

    def __str__(self):
        return '~~~%s奥特曼~~~\n' % self._name + \
            '生命值: %d\n' % self._hp + \
            '魔法值: %d\n' % self._mp


class Monster(Fighter):
    """小怪兽"""

    __slots__ = ('_name', '_hp')

    def attack(self, other):
        other.hp -= randint(10, 20)

    def __str__(self):
        return '~~~%s小怪兽~~~\n' % self._name + \
            '生命值: %d\n' % self._hp


def is_any_alive(monsters):
    """判断有没有小怪兽是活着的"""
    for monster in monsters:
        if monster.alive > 0:
            return True
    return False


def select_alive_one(monsters):
    """选中一只活着的小怪兽"""
    monsters_len = len(monsters)
    while True:
        index = randrange(monsters_len)
        monster = monsters[index]
        if monster.alive > 0:
            return monster


def display_info(ultraman, monsters):
    """显示奥特曼和小怪兽的信息"""
    print(ultraman)
    for monster in monsters:
        print(monster, end='')


def main():
    u = Ultraman('骆昊', 1000, 120)
    m1 = Monster('狄仁杰', 250)
    m2 = Monster('白元芳', 500)
    m3 = Monster('王大锤', 750)
    ms = [m1, m2, m3]
    fight_round = 1
    while u.alive and is_any_alive(ms):
        print('========第%02d回合========' % fight_round)
        m = select_alive_one(ms)  # 选中一只小怪兽
        skill = randint(1, 10)   # 通过随机数选择使用哪种技能
        if skill <= 6:  # 60%的概率使用普通攻击
            print('%s使用普通攻击打了%s.' % (u.name, m.name))
            u.attack(m)
            print('%s的魔法值恢复了%d点.' % (u.name, u.resume()))
        elif skill <= 9:  # 30%的概率使用魔法攻击(可能因魔法值不足而失败)
            if u.magic_attack(ms):
                print('%s使用了魔法攻击.' % u.name)
            else:
                print('%s使用魔法失败.' % u.name)
        else:  # 10%的概率使用究极必杀技(如果魔法值不足则使用普通攻击)
            if u.huge_attack(m):
                print('%s使用究极必杀技虐了%s.' % (u.name, m.name))
            else:
                print('%s使用普通攻击打了%s.' % (u.name, m.name))
                print('%s的魔法值恢复了%d点.' % (u.name, u.resume()))
        if m.alive > 0:  # 如果选中的小怪兽没有死就回击奥特曼
            print('%s回击了%s.' % (m.name, u.name))
            m.attack(u)
        display_info(u, ms)  # 每个回合结束后显示奥特曼和小怪兽的信息
        fight_round += 1
    print('\n========战斗结束!========\n')
    if u.alive > 0:
        print('%s奥特曼胜利!' % u.name)
    else:
        print('小怪兽胜利!')


if __name__ == '__main__':
    main()
# Out:
# ========第01回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了9点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 989
# 魔法值: 129
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 250
# ~~~白元芳小怪兽~~~
# 生命值: 500
# ~~~王大锤小怪兽~~~
# 生命值: 731
# ========第02回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 975
# 魔法值: 109
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 237
# ~~~白元芳小怪兽~~~
# 生命值: 490
# ~~~王大锤小怪兽~~~
# 生命值: 716
# ========第03回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 963
# 魔法值: 89
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 227
# ~~~白元芳小怪兽~~~
# 生命值: 479
# ~~~王大锤小怪兽~~~
# 生命值: 704
# ========第04回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 953
# 魔法值: 69
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 217
# ~~~白元芳小怪兽~~~
# 生命值: 464
# ~~~王大锤小怪兽~~~
# 生命值: 692
# ========第05回合========
# 骆昊使用究极必杀技虐了白元芳.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 936
# 魔法值: 19
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 217
# ~~~白元芳小怪兽~~~
# 生命值: 116
# ~~~王大锤小怪兽~~~
# 生命值: 692
# ========第06回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了7点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 922
# 魔法值: 26
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 217
# ~~~白元芳小怪兽~~~
# 生命值: 96
# ~~~王大锤小怪兽~~~
# 生命值: 692
# ========第07回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了4点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 902
# 魔法值: 30
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 217
# ~~~白元芳小怪兽~~~
# 生命值: 96
# ~~~王大锤小怪兽~~~
# 生命值: 669
# ========第08回合========
# 骆昊使用了魔法攻击.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 889
# 魔法值: 10
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 206
# ~~~白元芳小怪兽~~~
# 生命值: 85
# ~~~王大锤小怪兽~~~
# 生命值: 654
# ========第09回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了4点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 873
# 魔法值: 14
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 181
# ~~~白元芳小怪兽~~~
# 生命值: 85
# ~~~王大锤小怪兽~~~
# 生命值: 654
# ========第10回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了1点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 863
# 魔法值: 15
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 181
# ~~~白元芳小怪兽~~~
# 生命值: 67
# ~~~王大锤小怪兽~~~
# 生命值: 654
# ========第11回合========
# 骆昊使用魔法失败.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 851
# 魔法值: 15
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 181
# ~~~白元芳小怪兽~~~
# 生命值: 67
# ~~~王大锤小怪兽~~~
# 生命值: 654
# ========第12回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了2点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 834
# 魔法值: 17
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 181
# ~~~白元芳小怪兽~~~
# 生命值: 67
# ~~~王大锤小怪兽~~~
# 生命值: 633
# ========第13回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了8点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 824
# 魔法值: 25
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 164
# ~~~白元芳小怪兽~~~
# 生命值: 67
# ~~~王大锤小怪兽~~~
# 生命值: 633
# ========第14回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了5点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 808
# 魔法值: 30
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 164
# ~~~白元芳小怪兽~~~
# 生命值: 67
# ~~~王大锤小怪兽~~~
# 生命值: 610
# ========第15回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了7点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 790
# 魔法值: 37
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 164
# ~~~白元芳小怪兽~~~
# 生命值: 50
# ~~~王大锤小怪兽~~~
# 生命值: 610
# ========第16回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 774
# 魔法值: 17
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 151
# ~~~白元芳小怪兽~~~
# 生命值: 35
# ~~~王大锤小怪兽~~~
# 生命值: 599
# ========第17回合========
# 骆昊使用魔法失败.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 760
# 魔法值: 17
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 151
# ~~~白元芳小怪兽~~~
# 生命值: 35
# ~~~王大锤小怪兽~~~
# 生命值: 599
# ========第18回合========
# 骆昊使用魔法失败.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 749
# 魔法值: 17
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 151
# ~~~白元芳小怪兽~~~
# 生命值: 35
# ~~~王大锤小怪兽~~~
# 生命值: 599
# ========第19回合========
# 骆昊使用魔法失败.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 730
# 魔法值: 17
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 151
# ~~~白元芳小怪兽~~~
# 生命值: 35
# ~~~王大锤小怪兽~~~
# 生命值: 599
# ========第20回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了4点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 713
# 魔法值: 21
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 129
# ~~~白元芳小怪兽~~~
# 生命值: 35
# ~~~王大锤小怪兽~~~
# 生命值: 599
# ========第21回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 703
# 魔法值: 1
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 117
# ~~~白元芳小怪兽~~~
# 生命值: 23
# ~~~王大锤小怪兽~~~
# 生命值: 584
# ========第22回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了6点.
# ~~~骆昊奥特曼~~~
# 生命值: 703
# 魔法值: 7
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 117
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 584
# ========第23回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了2点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 690
# 魔法值: 9
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 95
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 584
# ========第24回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了3点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 678
# 魔法值: 12
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 80
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 584
# ========第25回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了6点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 659
# 魔法值: 18
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 80
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 561
# ========第26回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了7点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 645
# 魔法值: 25
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 55
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 561
# ========第27回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 633
# 魔法值: 5
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 41
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 550
# ========第28回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了7点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 613
# 魔法值: 12
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 41
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 533
# ========第29回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 603
# 魔法值: 12
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 41
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 533
# ========第30回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了2点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 585
# 魔法值: 14
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 41
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 515
# ========第31回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 565
# 魔法值: 14
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 41
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 515
# ========第32回合========
# 骆昊使用魔法失败.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 548
# 魔法值: 14
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 41
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 515
# ========第33回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了5点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 528
# 魔法值: 19
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 41
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 499
# ========第34回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了9点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 511
# 魔法值: 28
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 24
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 499
# ========第35回合========
# 骆昊使用了魔法攻击.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 495
# 魔法值: 8
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 9
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 489
# ========第36回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 478
# 魔法值: 9
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 9
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 474
# ========第37回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了4点.
# ~~~骆昊奥特曼~~~
# 生命值: 478
# 魔法值: 13
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 474
# ========第38回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 459
# 魔法值: 13
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 474
# ========第39回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了5点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 440
# 魔法值: 18
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 459
# ========第40回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了9点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 421
# 魔法值: 27
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 440
# ========第41回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 406
# 魔法值: 28
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 416
# ========第42回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了5点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 387
# 魔法值: 33
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 394
# ========第43回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了3点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 377
# 魔法值: 36
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 369
# ========第44回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了3点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 361
# 魔法值: 39
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 354
# ========第45回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 348
# 魔法值: 19
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 341
# ========第46回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了4点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 338
# 魔法值: 23
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 325
# ========第47回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了7点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 319
# 魔法值: 30
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 308
# ========第48回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了3点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 308
# 魔法值: 33
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 293
# ========第49回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了3点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 296
# 魔法值: 36
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 278
# ========第50回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了4点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 286
# 魔法值: 40
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 262
# ========第51回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了10点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 273
# 魔法值: 50
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 247
# ========第52回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 254
# 魔法值: 30
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 237
# ========第53回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了9点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 243
# 魔法值: 39
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 214
# ========第54回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 229
# 魔法值: 19
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 203
# ========第55回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 216
# 魔法值: 20
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 183
# ========第56回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了10点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 197
# 魔法值: 30
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 162
# ========第57回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 180
# 魔法值: 10
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 152
# ========第58回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了10点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 161
# 魔法值: 20
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 129
# ========第59回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了7点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 149
# 魔法值: 27
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 114
# ========第60回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了4点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 130
# 魔法值: 31
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 91
# ========第61回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 120
# 魔法值: 11
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 78
# ========第62回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了2点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 103
# 魔法值: 13
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 63
# ========第63回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 90
# 魔法值: 13
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 63
# ========第64回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了6点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 74
# 魔法值: 19
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 38
# ========第65回合========
# 骆昊使用魔法失败.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 62
# 魔法值: 19
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 38
# ========第66回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了3点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 42
# 魔法值: 22
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 20
# ========第67回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 31
# 魔法值: 2
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 8
# ========第68回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了8点.
# ~~~骆昊奥特曼~~~
# 生命值: 31
# 魔法值: 10
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 0
#
# ========战斗结束!========
#
# 骆昊奥特曼胜利!

# %%
import random


class Card(object):
    """一张牌"""

    def __init__(self, suite, face):
        self._suite = suite
        self._face = face

    @property
    def face(self):
        return self._face

    @property
    def suite(self):
        return self._suite

    def __str__(self):
        if self._face == 1:
            face_str = 'A'
        elif self._face == 11:
            face_str = 'J'
        elif self._face == 12:
            face_str = 'Q'
        elif self._face == 13:
            face_str = 'K'
        else:
            face_str = str(self._face)
        return '%s%s' % (self._suite, face_str)
    
    def __repr__(self):
        return self.__str__()


class Poker(object):
    """一副牌"""

    def __init__(self):
        self._cards = [Card(suite, face) 
                       for suite in '♠♥♣♦'
                       for face in range(1, 14)]
        self._current = 0

    @property
    def cards(self):
        return self._cards

    def shuffle(self):
        """洗牌(随机乱序)"""
        self._current = 0
        random.shuffle(self._cards)

    @property
    def next(self):
        """发牌"""
        card = self._cards[self._current]
        self._current += 1
        return card

    @property
    def has_next(self):
        """还有没有牌"""
        return self._current < len(self._cards)


class Player(object):
    """玩家"""

    def __init__(self, name):
        self._name = name
        self._cards_on_hand = []

    @property
    def name(self):
        return self._name

    @property
    def cards_on_hand(self):
        return self._cards_on_hand

    def get(self, card):
        """摸牌"""
        self._cards_on_hand.append(card)

    def arrange(self, card_key):
        """玩家整理手上的牌"""
        self._cards_on_hand.sort(key=card_key)


# 排序规则-先根据花色再根据点数排序
def get_key(card):
    return (card.suite, card.face)


def main():
    p = Poker()
    p.shuffle()
    players = [Player('东邪'), Player('西毒'), Player('南帝'), Player('北丐')]
    for _ in range(13):
        for player in players:
            player.get(p.next)
    for player in players:
        print(player.name + ':', end=' ')
        player.arrange(get_key)
        print(player.cards_on_hand)


if __name__ == '__main__':
    main()
# Out:
# 东邪: [♠A, ♣3, ♣7, ♣8, ♥7, ♥9, ♥K, ♦3, ♦5, ♦6, ♦8, ♦10, ♦Q]
# 西毒: [♠2, ♠3, ♠5, ♠7, ♠10, ♣2, ♣4, ♣9, ♣Q, ♥4, ♥6, ♥Q, ♦A]
# 南帝: [♠9, ♠J, ♠Q, ♠K, ♣J, ♥2, ♥5, ♥8, ♥J, ♦2, ♦7, ♦9, ♦K]
# 北丐: [♠4, ♠6, ♠8, ♣A, ♣5, ♣6, ♣10, ♣K, ♥A, ♥3, ♥10, ♦4, ♦J]

# %%
# 工资结算系统
"""
某公司有三种类型的员工 分别是部门经理、程序员和销售员
需要设计一个工资结算系统 根据提供的员工信息来计算月薪
部门经理的月薪是每月固定15000元
程序员的月薪按本月工作时间计算 每小时150元
销售员的月薪是1200元的底薪加上销售额5%的提成
"""
from abc import ABCMeta, abstractmethod

class Employee(object, metaclass=ABCMeta):
    """员工"""
    def __init__(self,name):
        """初始化方法
        :param name:姓名
        """
        self._name = name
        
    @property
    def name(self):
        return self._name
    
    @abstractmethod
    def get_salary(self):
        """
        工资计算
        """
        pass
    
class Manager(Employee):
    """部门经理"""
    def get_salary(self):
        return 15000.0
    
class Programmer(Employee):
    """程序员"""
    def __init__(self,name,working_hour=0):
        super().__init__(name)
        self._working_hour = working_hour
        
    @property
    def working_hour(self):
        return self._working_hour
    
    @working_hour.setter
    def working_hour(self,working_hour):
        self._working_hour = working_hour if working_hour>0 else 0
        
    def get_salary(self):
        return self._working_hour*150.0
    
class Salesman(Employee):
    """销售员"""
    def __init__(self,name,sales=0):
        super().__init__(name)
        self._sales = sales
        
    @property
    def sales(self):
        return self._sales
    
    @sales.setter
    def sales(self,sales):
        self._sales = sales if sales >0 else 0
        
    def get_salary(self):
        return self._sales*0.05+1200
    
def main():
    emps = [
        Manager('刘备'),Programmer('张飞'),Programmer('赵勇'),
        Salesman('吕布'),Salesman('关于')
    ]
    for emp in emps:
        if isinstance(emp,Programmer):
            emp.working_hour = int(input(f'输入{emp.name}本月工作时长:'))
        elif isinstance(emp,Salesman):
            emp.sales = int(input(f'输入{emp.name}本月销售额:'))
        print(f'{emp.name}本月工资为{emp.get_salary()}')
    
if __name__ == '__main__':
    main()
# Out:
# 刘备本月工资为15000.0
# 输入张飞本月工作时长: 50
# 张飞本月工资为7500.0
# 输入赵勇本月工作时长: 240
# 赵勇本月工资为36000.0
# 输入吕布本月销售额: 9000
# 吕布本月工资为1650.0
# 输入关于本月销售额: 100000
# 关于本月工资为6200.0
